# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Aquaculture_Exports.csv')

# %%
df
# Out:
#         SOURCE_ID       HS_CODE  \
# 0              63  3.021100e+08
# 1              63  3.021100e+08
# 2              63  3.021100e+08
# 3              63  3.021100e+08
# 4              63  3.021100e+08
# ...           ...           ...
# 368422         63  1.605520e+09
# 368423         63  1.605520e+09
# 368424         63  3.011100e+08
# 368425         63  3.011100e+08
# 368426         63  3.011100e+08
#
#                                            COMMODITY_DESC  GEOGRAPHY_CODE  \
# 0       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 1       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 2       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 3       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 4       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# ...                                                   ...             ...
# ...

# %%
df.head()
# Out:
#    SOURCE_ID      HS_CODE                                     COMMODITY_DESC  \
# 0         63  302110000.0  TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...
# 1         63  302110000.0  TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...
# 2         63  302110000.0  TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...
# 3         63  302110000.0  TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...
# 4         63  302110000.0  TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...
#
#    GEOGRAPHY_CODE GEOGRAPHY_DESC  ATTRIBUTE_DESC UNIT_DESC  YEAR_ID  \
# 0               1          World  US Export, QTY        KG     1989
# 1               1          World  US Export, QTY        KG     1989
# 2               1          World  US Export, QTY        KG     1989
# 3               1          World  US Export, QTY        KG     1989
# 4               1          World  US Export, QTY        KG     1989
#
#    TIMEPERIOD_ID  AMOUNT
# 0              2   17183
# 1              3    2327
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368427 entries, 0 to 368426
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SOURCE_ID       368427 non-null  int64
#  1   HS_CODE         224230 non-null  float64
#  2   COMMODITY_DESC  368427 non-null  object
#  3   GEOGRAPHY_CODE  368427 non-null  int64
#  4   GEOGRAPHY_DESC  368427 non-null  object
#  5   ATTRIBUTE_DESC  368427 non-null  object
#  6   UNIT_DESC       368427 non-null  object
#  7   YEAR_ID         368427 non-null  int64
#  8   TIMEPERIOD_ID   368427 non-null  int64
#  9   AMOUNT          368427 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 28.1+ MB

# %%
df.describe()
# Out:
#        SOURCE_ID       HS_CODE  GEOGRAPHY_CODE        YEAR_ID  TIMEPERIOD_ID  \
# count   368427.0  2.242300e+05   368427.000000  368427.000000  368427.000000
# mean        63.0  6.282936e+08     3344.099043    2003.979714       6.512704
# std          0.0  5.619946e+08     1999.455170       7.755908       3.479227
# min         63.0  3.011000e+08        1.000000    1989.000000       1.000000
# 25%         63.0  3.031900e+08     2010.000000    1997.000000       3.000000
# 50%         63.0  3.061600e+08     3510.000000    2005.000000       7.000000
# 75%         63.0  3.079900e+08     5081.000000    2011.000000      10.000000
# max         63.0  1.605906e+09     7990.000000    2016.000000      12.000000
#
#              AMOUNT
# count  3.684270e+05
# mean   3.588998e+05
# std    3.426469e+06
# min    1.500000e+01
# 25%    4.084000e+03
# 50%    1.956200e+04
# 75%    9.828000e+04
# max    3.214732e+08

# %%
df.shape
# Out:
# (368427, 10)

# %%
df.tail()
# Out:
#         SOURCE_ID       HS_CODE  \
# 368422         63  1.605520e+09
# 368423         63  1.605520e+09
# 368424         63  3.011100e+08
# 368425         63  3.011100e+08
# 368426         63  3.011100e+08
#
#                                            COMMODITY_DESC  GEOGRAPHY_CODE  \
# 368422  SCALLOPS, INCLUDING QUEEN SCALLOPS, PREPARED O...            2777
# 368423  SCALLOPS, INCLUDING QUEEN SCALLOPS, PREPARED O...            2777
# 368424                   ORNAMENTAL FRESHWATER FISH, LIVE            2777
# 368425                   ORNAMENTAL FRESHWATER FISH, LIVE            2777
# 368426                   ORNAMENTAL FRESHWATER FISH, LIVE            2777
#
#        GEOGRAPHY_DESC  ATTRIBUTE_DESC UNIT_DESC  YEAR_ID  TIMEPERIOD_ID  \
# 368422         Curaco  US Export, VLU     U.S.$     2014              7
# 368423         Curaco  US Export, VLU     U.S.$     2014              8
# 368424         Curaco  US Export, VLU     U.S.$     2012             11
# ...

# %%
df.isnull()
# Out:
#         SOURCE_ID  HS_CODE  COMMODITY_DESC  GEOGRAPHY_CODE  GEOGRAPHY_DESC  \
# 0           False    False           False           False           False
# 1           False    False           False           False           False
# 2           False    False           False           False           False
# 3           False    False           False           False           False
# 4           False    False           False           False           False
# ...           ...      ...             ...             ...             ...
# 368422      False    False           False           False           False
# 368423      False    False           False           False           False
# 368424      False    False           False           False           False
# 368425      False    False           False           False           False
# 368426      False    False           False           False           False
#
#         ATTRIBUTE_DESC  UNIT_DESC  YEAR_ID  TIMEPERIOD_ID  AMOUNT
# ...

# %%
df.notnull()
# Out:
#         SOURCE_ID  HS_CODE  COMMODITY_DESC  GEOGRAPHY_CODE  GEOGRAPHY_DESC  \
# 0            True     True            True            True            True
# 1            True     True            True            True            True
# 2            True     True            True            True            True
# 3            True     True            True            True            True
# 4            True     True            True            True            True
# ...           ...      ...             ...             ...             ...
# 368422       True     True            True            True            True
# 368423       True     True            True            True            True
# 368424       True     True            True            True            True
# 368425       True     True            True            True            True
# 368426       True     True            True            True            True
#
#         ATTRIBUTE_DESC  UNIT_DESC  YEAR_ID  TIMEPERIOD_ID  AMOUNT
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of         SOURCE_ID       HS_CODE  \
# 0              63  3.021100e+08
# 1              63  3.021100e+08
# 2              63  3.021100e+08
# 3              63  3.021100e+08
# 4              63  3.021100e+08
# ...           ...           ...
# 368422         63  1.605520e+09
# 368423         63  1.605520e+09
# 368424         63  3.011100e+08
# 368425         63  3.011100e+08
# 368426         63  3.011100e+08
#
#                                            COMMODITY_DESC  GEOGRAPHY_CODE  \
# 0       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 1       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 2       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 3       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 4       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# ...                                                   ...             ...
# ...

# %%
df.fillna
# Out:
# <bound method DataFrame.fillna of         SOURCE_ID       HS_CODE  \
# 0              63  3.021100e+08
# 1              63  3.021100e+08
# 2              63  3.021100e+08
# 3              63  3.021100e+08
# 4              63  3.021100e+08
# ...           ...           ...
# 368422         63  1.605520e+09
# 368423         63  1.605520e+09
# 368424         63  3.011100e+08
# 368425         63  3.011100e+08
# 368426         63  3.011100e+08
#
#                                            COMMODITY_DESC  GEOGRAPHY_CODE  \
# 0       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 1       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 2       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 3       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# 4       TROUT (SALMO TRUTTA, S. CLARKI ETC) FRESH, CHI...               1
# ...                                                   ...             ...
# ...
